# %% [markdown]
# # Cifar10 Classification

# %% [markdown]
# Until now, we have implemented several pieces of a deep learning pipeline and even trained a two-layer neural network, but all the hyperparameters were already set to some values yielding resonable results. In real-life problems, however, much of the work in a deep learning project will be geared towards finding the best hyperparameters for a certain problem. In this notebook we will explore some good practices for network debugging and hyperparameters search, as well as extending our previously binary classification neural network to a multi-class one.
#
# Let's go!

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Some lengthy setup.
import matplotlib.pyplot as plt
import numpy as np
import os
import urllib.request


from dl_zero2one.networks.layer import (
    Sigmoid, 
    Relu, 
    LeakyRelu, 
    Tanh,
)
from dl_zero2one.data import (
    DataLoader,
    ImageFolderDataset,
    RescaleTransform,
    NormalizeTransform,
    FlattenTransform,
    ComposeTransform,
)
from dl_zero2one.data.image_folder_dataset import RandomHorizontalFlip
from dl_zero2one.networks import (
    ClassificationNet,
    BCE,
    CrossEntropyFromLogits
)


# %matplotlib inline

plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# # 1. Quick recap (and some new things)

# %% [markdown]
# Until now, in the previous exercises, we focused on building and understanding all the necessary modules for training a simple model. We followed the Pytorch implementations closely, as this is the framework we will use later and we want you to have a smoother transition to its APIs.
#
# In the figure below you can see the main components in Pytorch. Before starting the actual exercise, we begin with a quick recap of **our implementation** of these components.

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/800/1*uZrS4KjAuSJQIJPgOiaJUg.png" style="width: 500px;">

# %% [markdown]
# ## 1.1 Dataset and Dataloader

# %% [markdown]
# Data preparation represents an important part of deep learning projects. The data comes from different sources and in different formats and is prepared differently from application to application. One part, however, is clear: because entire datasets are usually too large for us to handle at once, we train our models on smaller batches of data.
#
# The goal of the ```Dataset``` class is to encapsulate all the 'dirty' data processing: loading and cleaning the data, storing features (or names of files where features can be found) and labels, as well as providing the means for accessing individual (transformed) items of the data using the ```__getitem__()``` function and an index. You already implemented an ```ImageFolderDataset``` (in ```dl_zero2one/data/image_folder_dataset.py```) class in Exercise 4. We we will reuse this class here.
#
# For processing the data, you implemented several transforms in Exercise 4 (```RescaleTransform```, ```NormalizeTransform```, ```ComposeTransform```). In this exercise we are working with images, which are multidimensional arrays, but we are using simple feedforward neural network which takes a one dimensional array as an input, so it is necessary to reshape the images before feeding them into the model.
# from dl_zero2one.data.image_folder_dataset import FlattenTransform
#
# <div class="">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the reshape operation in the <code>FlattenTransform</code> class, which can be found in <code>/dl_zero2one/data/image_folder_dataset.py</code>. </p>
# </div>

# %%
# Set up the output dataset folder
working_path = os.path.dirname(os.path.abspath(os.getcwd()))
cifar_root = os.path.join(working_path, "datasets", "cifar10")

# Use the Cifar10 mean and standard deviation computed in Exercise 4.
cifar_mean = np.array([0.49191375, 0.48235852, 0.44673872])
cifar_std  = np.array([0.24706447, 0.24346213, 0.26147554])

# Define all the transforms we will apply on the images when 
# retrieving them.
rescale_transform = RescaleTransform()
normalize_transform = NormalizeTransform(
    mean=cifar_mean,
    std=cifar_std
)
flatten_transform = FlattenTransform()
compose_transform = ComposeTransform([rescale_transform, 
                                      normalize_transform,
                                      flatten_transform])

# Create a train, validation and test dataset.
datasets = {}
for mode in ['train', 'val', 'test']:
    crt_dataset = ImageFolderDataset(
        mode=mode,
        root=cifar_root, 
        transform=compose_transform,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2}
    )
    datasets[mode] = crt_dataset

# %% [markdown]
# Then, based on this ```Dataset``` object, we can construct a ```Dataloader``` object which samples a random mini-batch of data at once.

# %%
# Create a dataloader for each split.
dataloaders = {}
for mode in ['train', 'val', 'test']:
    crt_dataloader = DataLoader(
        dataset=datasets[mode],
        batch_size=256,
        shuffle=True,
        drop_last=True,
    )
    dataloaders[mode] = crt_dataloader

# %% [markdown]
# Because the ```Dataloader``` has the ```__iter__()``` method, we can simply iterate through the batches it produces, like this:
#
# ```python
# for batch in dataloader['train']:
#     do_something(batch)
# ```

# %% [markdown]
# ## 1.2 Data Augmentation
#
# After the above preprocessing steps, our data is in a good shape and ready to be fed into our network. As explained in the chapter above, we used the transformation functions `RescaleTransform`, `NormalizeTransform` and `FlattenTransform` to achieve this shape. These are the general steps that you need to perform on the data before we can even start the training. Of course, all these steps have to be applied to all three splits of our dataset (train, val and test split). So in other words, preprocessing involves preparing the data before they are used in training and inference.
#
# Besides these basic transformations, there are many other transformation methods that you can apply to the images. For example, you can <b>flip the images horizontally</b> or <b>blur the image</b> and use these new images to enlarge your dataset. This idea is called Data Augmentation and it involves methods that alter the training images to generate a synthetic dataset that is larger than your original dataset and will hopefully improve the performance of your model. The purpose here is different than in the data preprocessing steps and there is one big difference between data augmentation and data preprocessing: The transformation methods to enlarge your dataset should only be applied to the training data. The validation and test data are not affected by these methods.
#
# <div class="">
#     <h3>Task: Check Code</h3>
#     <p>The choice of transformation methods to use for data augmentation can be seen as a hyperparameter of your model and you can try to include these to enlarge your training data and obtain better results for your model. In <code>dl_zero2one/data/image_folder_dataset.py</code> we implemented the function <code>RandomHorizontalFlip</code> for you, which is randomly flipping an image. Check out the implementation.</p>
#     <p> Later, we will apply some hyperparameter tuning and in order to improve your model's accuracy, you could try to include some data augmentation methods. Fell free to play around and maybe also implement some other methods as for example Gaussian Blur or Rotation. </p>
# </div>
#
# Let us quickly check out the `RandomHorizontalFlip` method with an image of the Cifar10 dataset in the following cell.

# %%
#Load the data in a dataset without any transformation 
dataset = ImageFolderDataset(
        mode=mode,
        root=cifar_root, 
        split={'train': 0.6, 'val': 0.2, 'test': 0.2},
    )

#Retrieve an image from the dataset and flip it
image = dataset[1]['image']
transform = RandomHorizontalFlip(1)
image_flipped = transform(image)

#Show the two images
plt.figure(figsize = (2,2))
plt.subplot(1, 2, 1)
plt.imshow(image.astype('uint8'))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(image_flipped.astype('uint8'))
plt.axis('off')
plt.title("Left: Original Image, Right: Flipped image")
plt.show()

# %% [markdown]
# ## 1.3 Layers
#
# Now, that the data is prepared, we can discuss the model in which we are feeding the data. In our case the model will be a neural network.
#
# In Exercise 5, you implemented a simple 2-layer neural network that had a hidden size as a parameter:
#
# $$
# {\hat{y}} = \sigma(\sigma({x W_1} + {b_1}) {W_2} + {b_2})
# $$
#
# where $ \sigma({x}) $ was the sigmoid function, $ {x} $ was the input, $ {W_1}, {W_2} $ the weight matrices and $ {b_1}, {b_2}$ the biases for the two layers.
#
# This is how we used this network:

# %%
input_size = datasets['train'][0]['image'].shape[0]
model = ClassificationNet(input_size=input_size, 
                          hidden_size=512)

# %% [markdown]
# Note that we updated the ```ClassificationNet``` from the previous exercise, so that now you can customize more: the number of outputs, the choice of activation function, the hidden size etc. We encourage you to check out the implementation in ```dl_zero2one/networks/classification_net.py```

# %%
num_layer = 2
reg = 0.1

model = ClassificationNet(activation=Sigmoid(), 
                          num_layer=num_layer, 
                          reg=reg,
                          num_classes=10)

# %% [markdown]
# Then, the forward and backward passes through the model were simply:
#
# ```python
#
# # X is a batch of training features
# # X.shape = (batch_size, features_size)
# y_out = model.forward(X)
#
# # dout is the gradient of the loss function w.r.t the output of the network.
# # dout.shape = (batch_size, )
# model.backward(dout)
# ```

# %% [markdown]
# **Just** as the learning rate or the number of iterations we want to train for, the number of hidden layers and the number of units in each hidden layer are also hyperparameters. In this notebook you will play with networks of different sizes and will see the impact that the network capacity has.
#
# Before we move on to the loss functions, we want to have a look at the activation functions. The choice of an activation function can have a huge impact on the performance of the network that you are designing. So far, you have implemented the `Sigmoid` and the `Relu` activation function in Exercise 5.
#
# <div class="">
#     <h3>Task: Check Code</h3>
#     <p>Take a look at the <code>Sigmoid</code> and the <code>Relu</code> class in <code>dl_zero2one/networks/layer.py</code> and the implementation of the respective forward and backward pass. Make sure to understand why we use <b>element-wise product</b> instead of dot product in the backward pass of the <code>Sigmoid</code> class to compute the gradient $dx$. That will be helpful for your later implementation of other activation functions.</p>
#     <p> <b>Note:</b> The <code>cache</code> variable is used to store information from the forward pass and then pass this information in the backward pass to make use of it there. The implementation of both classes show that this variable can be used differently - depending on what information is needed in the backward pass. </p>
# </div>
#
# Now, we want to have a look at two other, very common activation functions that you have already met in the lecture: Leaky ReLU activation function and Tanh activation function.
#
# **Leaky Relus** are one attempt to fix the “dying ReLU” problem. Instead of the function being zero when $x<0$, a leaky ReLU has a small negative slope (for example, 0.01). That is, the function computes $f(x) = \mathbb{1}(x < 0) (\alpha x) + \mathbb{1}(x>=0) (x)$ where $\alpha$ is a small constant. Some people report success with this form of activation function, but the results are not always consistent.
#
# The **tanh non-linearity** squashes a real-valued number to the range [-1, 1]. Like the sigmoid neuron, its activations saturate, but unlike the sigmoid neuron its output is zero-centered. Therefore, in practice the tanh non-linearity is always preferred to the sigmoid non-linearity. Also note that the tanh neuron is simply a scaled sigmoid neuron, in particular the following holds: $\tanh(x) = 2 \cdot \sigma(2x) -1$.
#
# <img class=left src=https://pytorch.org/docs/stable/_images/LeakyReLU.png alt="Figure3" width="350" align='left'/>
# <img class=right src=https://pytorch.org/docs/stable/_images/Tanh.png alt="Figure4" width="350"/>
#
# <div class="">
#     <h3>Task: Check Activation Layers</h3>
#     <p> Now, it is your turn to check the <code>LeakyRelu</code> and the <code>Tanh</code> class in <code>dl_zero2one/networks/layer.py</code> <code>forward</code> and the <code>backward</code> functions. </p>
#     <p> <b>Note:</b> Always remember to return a cache in <code>forward</code> for later backpropagation in <code>backward</code>. As we have seen above, the <code>cache</code> variable can be used differently for two activation functions.</p>
# </div>

# %% [markdown]
# Congratulations, you now implemented all four different activation functions! These activation layers are now ready to be used when you start building your own network.

# %% [markdown]
# ## 1.4 Loss
#
# In order to measure how well a network is performing, we implemented several ```Loss``` classes (```L1```, ```MSE```, ```BCE```, each preferred for a certain type of problems) in ```dl_zero2one/networks/loss.py```.
#
#
#
# Also, because our goal was to change the weights of the network such that this loss measure decreases, we were also interested in the gradients of the loss w.r.t the outputs of the network, $ \nabla_{\hat{y}} L({\hat{y}}, {y}) $. This was implemented in ```backward()```.
#
# In previous exercises, we only worked with binary classification and used binary cross entropy (```BCE```) as a loss function.
#
# $$ BCE(\hat{y}, y) = \frac{1}{N} \sum_{i=1}^N \Big [-y_i \log(\hat{y_i}) - (1-y_i) \log(1 - \hat{y_i}) \Big] $$
#
# where
# - $ N $ was the number of samples we were considering
# - $\hat{y}_i$ was the network's prediction for sample $i$. Note that this was a valid probability $\in [0, 1]$, because we applied a [sigmoid](https://en.wikipedia.org/wiki/Sigmoid_function) activation on the last layer.
# - $ y_i $ was the ground truth label (0 or 1, depending on the class)
#
# Because we have 10 classes in the CIFAR10 dataset, we need a generalization of the binary cross entropy for multiple classes. This is simply called the cross entropy loss and has the following definition:
#
# $$ CE(\hat{y}, y) = \frac{1}{N} \sum_{i=1}^N \sum_{k=1}^{C} \Big[ -y_{ik} \log(\hat{y}_{ik}) \Big] $$
#
# where:
# - $ N $ is again the number of samples
# - $ C $ is the number of classes
# - $ \hat{y}_{ik} $ is the probability that the model assigns for the $k$th class when the $i$th sample is the input. **Because we don't apply any activation function on the last layer of our network, its outputs for each sample will not be a valid probability distribution over the classes. We call these raw outputs of the network '[logits](https://datascience.stackexchange.com/questions/31041/what-does-logits-in-machine-learning-mean/31045)' and we will apply a [softmax](https://en.wikipedia.org/wiki/Softmax_function) activation in order to obtain a valid probability distribution.**
# - $y_{ik} = 1 $ iff the true label of the $i$th sample is $k$ and 0 otherwise. This is called a [one-hot encoding](https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/).
#
# You can check for yourself that when the number of classes $ C $ is 2, then the binary cross entropy is actually equivalent to the cross entropy.
#
# <div class="">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the <code>CrossEntropyFromLogits</code> class, which can be found in <code>../exercise_06/dl_zero2one/networks/loss.py</code>. </p>
# </div>

# %%
loss = CrossEntropyFromLogits()

# %% [markdown]
# Just as with the previous losses we have seen, we can simply get the results of the forward and backward passes as follows:

# %% [markdown]
# ```python
# # y_out is the output of the neural network
# # y_truth is the actual label from the dataset
# loss.forward(y_out, y_truth)
# loss.backward(y_out, y_truth)
# ```

# %% [markdown]
# ## 1.5 Optimizer
#
# Now, knowing the gradient of the loss w.r.t the ouputs of the network, as well as the local gradient for each layer of the network, we can use the chain rule to compute all gradients.
#
# <div class="">
#     <h3>Task: Check Code</h3>
#     <p>We implemented several optimizer classes <code>SGD</code>, <code>Adam</code>, <code>sgd_momentum</code> class that implement different first-order parameter update rules, which can be found in <code>dl_zero2one/networks/optimizer.py</code>. </p>
#     <p>The <code>step()</code> method iterates through all the parameters of a model and updates them using the gradient information.</p>
# </div>
#
# What the optimizer is doing, in pseudocode, is the following:
#
# ```python
# for param in model:
#     # Use the gradient to update the weights.
#     update(param)
#
#     # Reset the gradient after each update.
#     param.gradient = 0
# ```
#
# ```SGD``` had the simplest update rule:
# ```python
# def update(param):
#     param = param - learning_rate * param.gradient
# ```
#
# For the more complicated update rules, see ```dl_zero2one/networks/optimizer.py```

# %% [markdown]
# ## 1.6 Solver
#
# The ```Solver``` is where all the above elements come together: Given a train and a validation dataloader, a model, a loss and an optimizer, it uses the training data to optimize a model in order to get better predictions. We simply call ```train()``` and it does its 'magic' for us!
# ```python
# solver = Solver(model,
#                 dataloaders['train'],
#                 dataloaders['val'],
#                 learning_rate=0.001,
#                 loss_func=MSE(),
#                 optimizer=SGD)
#
# solver.train(epochs=epochs)
# ```
#
# <div class="">
#     <h3>Task: Check Code</h3>
#     <p>Please check out the implementation of <code>train()</code> in <code>/dl_zero2one/solver.py</code>. </p>
# </div>

# %% [markdown]
# ## 1.7 Weight Regularization
#
# Before we finish this section of recap, we want to take a look at some regularization method that has been introduced in the lecture and that is super helpful to improve robustness of our model. Here, we talk about weight regularization.
#
# Weight regularization has been introduced to you as a method preventing our model from overfitting. Essentially, it is a term (solely depending on the weights of our model) that is added to the final loss and that encodes some preference for a certain set of weights $W$ over others. In the lecture, we compared two weight regularization methods and their respective preference for weight vectors. We made the following observation:
#
# 1. L1 regularization: Enforces sparsity
# 2. L2 regularization: Enforces that weights have similar values
#
# The most common weight regularization method is the L2 regularization. From the observations made in the lecture that makes totally sense - at least when we compare it to the L1 regularization. The L2 regularization penalty in the loss prefers smaller and more diffuse weight vectors and hence the model is encouraged to take into account all input dimensions to small amounts rather than a few input dimensions and very strongly.
#
# When using weight regularization, the loss function is a composition of two parts:
# $$L = \underbrace{\frac{1}{N} \sum_{i} L_i}_{\text{data loss}}  + \underbrace{\lambda R(W)}_{\text{regularization loss}}$$
# The first one being the data loss, which is calculated with the Cross Entropy loss in our model. The second part is called the regularization loss $R(W)$ and is computed in the L2 case as follows:
# $$R(W) = \sum_{k} \sum_{l} w_{k,l}^2$$

# %% [markdown]
# # 2. An overview of hyperparameters

# %% [markdown]
# <img src=https://images.deepai.org/glossary-terms/05c646fe1676490aa0b8cab0732a02b2/hyperparams.png alt=hyperparameter width=700>
#
# A **hyperparameter** is a parameter that is set before the learning process begins. Recall that the parameters of weight matrix and bias vector are learned during the learning process.
#
# The hyperparameters are essential, for they control and affect the whole training and have a great impact on the performance of the model.
#
# Some examples of hyperparameters we have covered in lectures:
# * Network architecture
#     * Choice of activation function
#     * Number of layers
#     * ...
# * Learning rate
# * Number of epochs
# * Batch size
# * Regularization strength
# * Momentum
# * ...

# %% [markdown]
# ## 2.1 Start debugging your own network!

# %% [markdown]
# As already suggested in the lectures, you may always want to start from small and simple architectures, to make sure you are going the right way.
#
# First you may need to overfit a single training sample, then a few batches of training samples, then go deeper with larger neural networks and the whole training data.
#
# Here we always provide a default neural network (i.e. ClassificationNet) with arbitrary number of layers, which is a generalization from a fixed 2-layer neural network in exercise 5. You are welcome to implement your own network, in that case just implement **MyOwnNetwork** in ```dl_zero2one/networks/classification_net.py```. You can also copy things from ClassficationNet and make a little adjustment to your own network. For either way, just pick a network and comment out the other one, then run the cells below for debugging.
#
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>Please, make sure you don't modify the ClassificationNet itself so that you can always have a working network to fall back on</p>
#     <p> The goal is to find reasonable hyperparameters and the parameter options of the ClassificationNet are broad enough.</p>
#     <p>You can also try to implement additional activation functions in the accompanying notebook, try different weight initializations or other adjustments by writing your own network architecture in the MyOwnNetwork class.</p>
# </div>

# %% [markdown]
# First, let's begin with a 2-layer neural network, and overfit one single training sample.
#
# After training, let's evaluate the training process by plotting the loss curves.

# %%
from dl_zero2one.solver import Solver
from dl_zero2one.networks.optimizer import SGD, Adam
from dl_zero2one.networks import MyOwnNetwork

num_layer = 2
epochs = 20
reg = 0.1
batch_size = 4

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

loss = CrossEntropyFromLogits()

# Make a new data loader with a single training image
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    transform=compose_transform,
    limit_files=1
)
dataloaders['train_overfit_single_image'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

# Decrease validation data for only debugging
debugging_validation_dataset = ImageFolderDataset(
    mode='val',
    root=cifar_root, 
    transform=compose_transform,
    limit_files=100
)
dataloaders['val_500files'] = DataLoader(
    dataset=debugging_validation_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

solver = Solver(model, dataloaders['train_overfit_single_image'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 20) train loss: 2.333026; val loss: 2.333503
# (Epoch 2 / 20) train loss: 2.333026; val loss: 2.321706
# (Epoch 3 / 20) train loss: 2.310188; val loss: 2.321885
# (Epoch 4 / 20) train loss: 2.233066; val loss: 2.326303
# (Epoch 5 / 20) train loss: 2.050003; val loss: 2.333198
# (Epoch 6 / 20) train loss: 1.786529; val loss: 2.342477
# (Epoch 7 / 20) train loss: 1.502044; val loss: 2.353899
# (Epoch 8 / 20) train loss: 1.226925; val loss: 2.367450
# (Epoch 9 / 20) train loss: 0.970379; val loss: 2.382028
# (Epoch 10 / 20) train loss: 0.758406; val loss: 2.397249
# (Epoch 11 / 20) train loss: 0.571191; val loss: 2.412972
# (Epoch 12 / 20) train loss: 0.420693; val loss: 2.428609
# (Epoch 13 / 20) train loss: 0.312027; val loss: 2.442801
# (Epoch 14 / 20) train loss: 0.226558; val loss: 2.455337
# (Epoch 15 / 20) train loss: 0.171905; val loss: 2.465334
# (Epoch 16 / 20) train loss: 0.139392; val loss: 2.471888
# (Epoch 17 / 20) train loss: 0.121159; val loss: 2.474276
# (Epoch 18 / 20) train loss: 0.112713; val loss: 2.472801
# (Epoch 19 / 20) train loss: 0.111564; val loss: 2.467608
# (Epoch 20 / 20) train loss: 0.116629; val loss: 2.460592

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_single_image'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 0.08000

# %% [markdown]
# This time let's try to overfit to a small set of training batch samples. Please observe the difference from above.

# %%
from dl_zero2one.networks import MyOwnNetwork

num_layer = 2
epochs = 100
reg = 0.1
num_samples = 10

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

loss = CrossEntropyFromLogits()

# Make a new data loader with a our num_samples training image
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_overfit_10samples'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

solver = Solver(model, dataloaders['train_overfit_10samples'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 100) train loss: 2.333228; val loss: 2.333451
# (Epoch 2 / 100) train loss: 2.320288; val loss: 2.308204
# (Epoch 3 / 100) train loss: 2.293267; val loss: 2.313697
# (Epoch 4 / 100) train loss: 2.213876; val loss: 2.320662
# (Epoch 5 / 100) train loss: 2.193388; val loss: 2.331357
# (Epoch 6 / 100) train loss: 2.087205; val loss: 2.341695
# (Epoch 7 / 100) train loss: 2.002788; val loss: 2.412013
# (Epoch 8 / 100) train loss: 1.839208; val loss: 2.536452
# (Epoch 9 / 100) train loss: 1.822522; val loss: 2.623944
# (Epoch 10 / 100) train loss: 1.843176; val loss: 2.735842
# (Epoch 11 / 100) train loss: 1.738688; val loss: 3.054743
# (Epoch 12 / 100) train loss: 1.674249; val loss: 3.647625
# (Epoch 13 / 100) train loss: 1.618482; val loss: 4.179536
# (Epoch 14 / 100) train loss: 1.689262; val loss: 4.499745
# (Epoch 15 / 100) train loss: 1.769082; val loss: 4.650602
# (Epoch 16 / 100) train loss: 1.819138; val loss: 4.551436
# (Epoch 17 / 100) train loss: 1.862448; val loss: 4.399411
# (Epoch 18 / 100) train loss: 1.713137; val loss: 4.178908
# (Epoch 19 / 100) train loss: 1.801506; val loss: 3.856338
# (Epoch 20 / 100) train loss: 1.653637; val loss: 3.800770
# (Epoch 21 / 100) train loss: 1.649010; val loss: 3.780622
# (Epoch 22 / 100) train loss: 1.814437; val loss: 3.729804
# (Epoch 23 / 100) train loss: 1.742724; val loss: 3.717565
# (Epoch 24 / 100) train loss: 1.661228; val loss: 3.951228
# (Epoch 25 / 100) train loss: 1.813883; val loss: 4.096242
# (Epoch 26 / 100) train loss: 1.814552; val loss: 4.044419
# (Epoch 27 / 100) train loss: 1.848051; val loss: 4.217064
# (Epoch 28 / 100) train loss: 1.720222; val loss: 4.307669
# (Epoch 29 / 100) train loss: 1.825196; val loss: 4.346424
# (Epoch 30 / 100) train loss: 1.790286; val loss: 4.415050
# (Epoch 31 / 100) train loss: 1.873287; val loss: 4.433246
# (Epoch 32 / 100) train loss: 1.775890; val loss: 4.709514
# (Epoch 33 / 100) train loss: 1.822118; val loss: 5.149887
# (Epoch 34 / 100) train loss: 2.048003; val loss: 5.291470
# (Epoch 35 / 100) train loss: 1.822029; val loss: 5.343321
# (Epoch 36 / 100) train loss: 1.835229; val loss: 5.367240
# (Epoch 37 / 100) train loss: 1.806894; val loss: 5.260044
# (Epoch 38 / 100) train loss: 1.752597; val loss: 5.024319
# (Epoch 39 / 100) train loss: 1.668213; val loss: 5.019290
# (Epoch 40 / 100) train loss: 1.920651; val loss: 4.753802
# (Epoch 41 / 100) train loss: 1.812936; val loss: 4.177562
# (Epoch 42 / 100) train loss: 1.634069; val loss: 3.793846
# (Epoch 43 / 100) train loss: 1.690713; val loss: 3.565434
# (Epoch 44 / 100) train loss: 1.692962; val loss: 3.474901
# (Epoch 45 / 100) train loss: 1.717984; val loss: 3.533520
# (Epoch 46 / 100) train loss: 1.680587; val loss: 3.631570
# (Epoch 47 / 100) train loss: 1.573267; val loss: 3.779048
# (Epoch 48 / 100) train loss: 1.606528; val loss: 3.973079
# (Epoch 49 / 100) train loss: 1.678760; val loss: 4.239996
# (Epoch 50 / 100) train loss: 1.714678; val loss: 4.362036
# (Epoch 51 / 100) train loss: 1.889930; val loss: 4.279504
# (Epoch 52 / 100) train loss: 1.967115; val loss: 4.363174
# (Epoch 53 / 100) train loss: 1.954816; val loss: 4.658119
# (Epoch 54 / 100) train loss: 1.924146; val loss: 4.798515
# (Epoch 55 / 100) train loss: 1.814536; val loss: 4.697799
# (Epoch 56 / 100) train loss: 1.835019; val loss: 4.558610
# (Epoch 57 / 100) train loss: 1.717156; val loss: 4.486094
# (Epoch 58 / 100) train loss: 1.808703; val loss: 4.392045
# (Epoch 59 / 100) train loss: 1.815821; val loss: 4.279482
# (Epoch 60 / 100) train loss: 1.717755; val loss: 4.242878
# (Epoch 61 / 100) train loss: 1.695957; val loss: 4.211442
# (Epoch 62 / 100) train loss: 1.786696; val loss: 4.165105
# (Epoch 63 / 100) train loss: 1.778894; val loss: 4.181825
# (Epoch 64 / 100) train loss: 1.945240; val loss: 4.206640
# (Epoch 65 / 100) train loss: 1.853088; val loss: 4.179209
# (Epoch 66 / 100) train loss: 1.868871; val loss: 4.133356
# (Epoch 67 / 100) train loss: 1.737394; val loss: 4.245628
# (Epoch 68 / 100) train loss: 1.828095; val loss: 4.433915
# (Epoch 69 / 100) train loss: 1.945957; val loss: 4.497477
# (Epoch 70 / 100) train loss: 1.934189; val loss: 4.542014
# (Epoch 71 / 100) train loss: 1.739196; val loss: 4.640614
# (Epoch 72 / 100) train loss: 1.697507; val loss: 4.624339
# (Epoch 73 / 100) train loss: 1.789970; val loss: 4.611671
# (Epoch 74 / 100) train loss: 1.643691; val loss: 4.614294
# (Epoch 75 / 100) train loss: 1.700768; val loss: 4.631950
# (Epoch 76 / 100) train loss: 1.641092; val loss: 4.599856
# (Epoch 77 / 100) train loss: 1.662845; val loss: 4.486322
# (Epoch 78 / 100) train loss: 1.616769; val loss: 4.350824
# (Epoch 79 / 100) train loss: 1.571617; val loss: 4.206372
# (Epoch 80 / 100) train loss: 1.594357; val loss: 4.095074
# (Epoch 81 / 100) train loss: 1.664743; val loss: 4.063536
# (Epoch 82 / 100) train loss: 1.769253; val loss: 4.174530
# (Epoch 83 / 100) train loss: 1.639264; val loss: 4.338047
# (Epoch 84 / 100) train loss: 1.710731; val loss: 4.356503
# (Epoch 85 / 100) train loss: 1.630778; val loss: 4.338803
# (Epoch 86 / 100) train loss: 1.669492; val loss: 4.461753
# (Epoch 87 / 100) train loss: 1.565428; val loss: 4.713511
# (Epoch 88 / 100) train loss: 1.629610; val loss: 5.206949
# (Epoch 89 / 100) train loss: 1.618472; val loss: 5.728582
# (Epoch 90 / 100) train loss: 2.023645; val loss: 5.853349
# (Epoch 91 / 100) train loss: 1.883138; val loss: 5.591959
# (Epoch 92 / 100) train loss: 1.946860; val loss: 5.459780
# (Epoch 93 / 100) train loss: 1.895141; val loss: 5.672545
# (Epoch 94 / 100) train loss: 1.851805; val loss: 5.905242
# (Epoch 95 / 100) train loss: 2.212898; val loss: 6.201440
# (Epoch 96 / 100) train loss: 1.965631; val loss: 6.150745
# (Epoch 97 / 100) train loss: 1.953003; val loss: 6.087808
# (Epoch 98 / 100) train loss: 2.028806; val loss: 5.892332
# (Epoch 99 / 100) train loss: 1.903786; val loss: 5.617052
# (Epoch 100 / 100) train loss: 2.083526; val loss: 5.478336

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_10samples'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 0.08000

# %% [markdown]
# If you're overfitting the training data, that means the network's implementation is correct. However, as you have more samples to overfit, your accuracy will be way lower. You can increase the number of epochs above to achieve better results.
#
# Now let's try to feed all the training and validation data into the network, but this time we set the same hyperparameters for 2-layer and 5-layer networks, and compare the different behaviors.
#
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>This may take about 1 min for each epoch as the training set is quite large. For convenience, we only train on 1000 images for now but use the full validation set.</p>
# </div>

# %%
from dl_zero2one.networks import MyOwnNetwork

num_layer = 2
epochs = 10
reg = 0.01

# Make a new data loader with 1000 training samples
num_samples = 1000
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_small'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)


# Change here if you want to use the full training set
use_full_training_set = False
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']
    

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

loss = CrossEntropyFromLogits()

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 10) train loss: 2.305706; val loss: 2.305689
# (Epoch 2 / 10) train loss: 2.393250; val loss: 2.356917
# (Epoch 3 / 10) train loss: 2.377383; val loss: 2.246354
# (Epoch 4 / 10) train loss: 2.293993; val loss: 2.299406
# (Epoch 5 / 10) train loss: 2.376553; val loss: 2.288218
# (Epoch 6 / 10) train loss: 2.313324; val loss: 2.294241
# (Epoch 7 / 10) train loss: 2.322658; val loss: 2.395876
# (Epoch 8 / 10) train loss: 2.282742; val loss: 2.349494
# (Epoch 9 / 10) train loss: 2.299986; val loss: 2.343997
# (Epoch 10 / 10) train loss: 2.288804; val loss: 2.379341

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 0.24800
# Validation accuray: 0.22516

# %%
from dl_zero2one.networks import MyOwnNetwork

num_layer = 5
epochs = 10
reg = 0.01

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

# Change here if you want to use the full training set
use_full_training_set = False
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']

loss = CrossEntropyFromLogits()

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 10) train loss: 2.305965; val loss: 2.305965
# (Epoch 2 / 10) train loss: 2.302768; val loss: 2.302643
# (Epoch 3 / 10) train loss: 2.302069; val loss: 2.302803
# (Epoch 4 / 10) train loss: 2.301662; val loss: 2.302973
# (Epoch 5 / 10) train loss: 2.301292; val loss: 2.303159
# (Epoch 6 / 10) train loss: 2.300961; val loss: 2.303430
# (Epoch 7 / 10) train loss: 2.300838; val loss: 2.303596
# (Epoch 8 / 10) train loss: 2.300617; val loss: 2.303792
# (Epoch 9 / 10) train loss: 2.300597; val loss: 2.303966
# (Epoch 10 / 10) train loss: 2.300472; val loss: 2.304256

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 0.11300
# Validation accuray: 0.10026

# %% [markdown]
# As you can see from above, the same hyperparameter set can decrease the loss for a 5-layer network, but for 2-layer network, it hardly works.
#
# The steps above are already mentioned in the lectures as debugging steps before training a neural network.
#
# If you implement your own network, make sure you do the steps above before tuning the hyperparameters as below.

# %% [markdown]
# ## 2.2 Difficulty in tuning hyperparameters
# As can be seen through the results of training a larger network, training with whole data doesn't fit the training data as well as training with small number of training data. Besides, the architecture of neural network makes a difference, too. Small decisions on hyperparameters count.
#
# Usually, but not always, hyperparameters cannot be learned using well known gradient based methods (such as gradient descent), which are commonly employed to learn parameters. Besides, some hyperparameters can affect the structure of the model and the loss function.
#
# As mentioned before, hyperparameters need to be set before training. Tuning hyperparameters is hard, because you always have to try different combinations of the hyperparameters, train the network, do the validation and pick the best one. Besides, it is not guaranteed that you'll find the best combination.
#
# Next you will do hands on learning with hyperparameter tuning methods that are covered in lectures.

# %% [markdown]
# # 3. Hyperparameter Tuning
#
# ![alt text](https://blog.floydhub.com/content/images/2018/08/Screen-Shot-2018-08-22-at-17.59.25.png "")
#
# One of the main challenges in deep learning is finding the set of hyperparameters that performs best.
#
# So far, we have followed a manual approach by guessing hyperparameters, running the model, observing the result and maybe tweaking the hyperparameters based on this result. As you have probably noticed, this manual hyperparameter tuning is unstructured, inefficient and can become very tedious.
#
#
# A more systematic (and actually very simple) approach for hyperparameter tuning that you've already learned in the lecture  is implementing a **Grid Search**.
#
#
#
# ## 3.1 Grid Search
# Grid search is a simple and naive, yet effective method to automate the hyperparameter tuning:
#
# * First, you define the set of parameters you want to tune, e.g. $\{learning\_rate, regularization\_strength\}$.
#
# * For each hyperparameter, you then define a set of possible values, e.g. $learning\_rate = \{0.0001, 0.001, 0.01, 0.1\}$.
#
# * Then, you train a model for every possible combination of these hyperparameter values and afterwards select the combination that works best (e.g. in terms of accuracy on your validation set).
#
# <div class="">
#     <h3>Task: Check Code</h3>
#     <p>Check out the <code>grid_search</code> implementation in <code>dl_zero2one/hyperparameter_tuning.py</code>. We show a simple for loop implementation and a more sophisticated one for multiple inputs. </p>
# </div>
#
#  <div class="">
#     <h3>Note:</h3>
#     <p>To keep things simple for the beginning, it'll be enough to just focus on the hyperparameters <code>learning_rate</code> and <code>regularization_strength</code> here, as in the example above.</p>
# </div>

# %%
from dl_zero2one.networks import MyOwnNetwork

# Specify the used network
model_class = ClassificationNet

from dl_zero2one import hyperparameter_tuning
best_model, results = hyperparameter_tuning.grid_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    grid_search_spaces = {
        "learning_rate": [1e-2, 1e-3, 1e-4], 
        "reg": [1e-4]
    },
    model_class=model_class,
    epochs=10, patience=5)
# Out:
# Evaluating Config #1 [of 3]:
#  {'learning_rate': 0.01, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302627; val loss: 2.302612
# /Users/matthiaskiller/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/networks/loss.py:155: RuntimeWarning: divide by zero encountered in log
#   loss = -y_truth_one_hot * np.log(y_out_probs)
# /Users/matthiaskiller/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/networks/loss.py:155: RuntimeWarning: invalid value encountered in multiply
#   loss = -y_truth_one_hot * np.log(y_out_probs)
# (Epoch 2 / 10) train loss: nan; val loss: 70.387258
# (Epoch 3 / 10) train loss: nan; val loss: nan
# (Epoch 4 / 10) train loss: nan; val loss: nan
# (Epoch 5 / 10) train loss: nan; val loss: nan
# (Epoch 6 / 10) train loss: nan; val loss: nan
# Stopping early at epoch 5!
#
# Evaluating Config #2 [of 3]:
#  {'learning_rate': 0.001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302598; val loss: 2.302580
# (Epoch 2 / 10) train loss: 2.428950; val loss: 2.317570
# (Epoch 3 / 10) train loss: 2.484145; val loss: 2.652496
# (Epoch 4 / 10) train loss: 2.618299; val loss: 2.447747
# (Epoch 5 / 10) train loss: 2.846621; val loss: 2.611140
# (Epoch 6 / 10) train loss: 2.959960; val loss: 2.876422
# Stopping early at epoch 5!
#
# Evaluating Config #3 [of 3]:
#  {'learning_rate': 0.0001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302599; val loss: 2.302644
# (Epoch 2 / 10) train loss: 2.226305; val loss: 2.118507
# (Epoch 3 / 10) train loss: 2.143846; val loss: 2.135028
# (Epoch 4 / 10) train loss: 2.118066; val loss: 2.142369
# (Epoch 5 / 10) train loss: 2.110288; val loss: 2.141842
# (Epoch 6 / 10) train loss: 2.104779; val loss: 2.124647
# (Epoch 7 / 10) train loss: 2.098488; val loss: 2.126242
# Stopping early at epoch 6!
#
# Search done. Best Val Loss = 2.1185074568552182
# Best Config: {'learning_rate': 0.0001, 'reg': 0.0001}

# %% [markdown]
# From the results of your grid search, you might already have found some hyperparameter combinations that work better than others. A common practice is to now repeat the grid search on a more narrow domain centered around the parameters that worked best.
#
# **Conclusion Grid Search**
#
# With grid search we now have automated the hyperparameter tuning to a certain degree. Another advantage is, that since the training of all models are independent of each other, you can parallelize the grid search, i.e.,  try out different hyperparameter configurations in parallel on different machines.
#
# However, as you have probably noticed, there is one big problem with this approach: the number of possible combinations to try out grows exponentially with the number of hyperparameters ("curse of dimensionality"). As we add more hyperparameters to the grid search, the search space will explode in time complexity, making this strategy unfeasible.

# %% [markdown]
# Especially when your search space contains more than 3 or 4 dimensions, it is often better to use another, similar hyperparameter tuning method that you've already learned about: random search.

# %% [markdown]
# ## 3.2 Random Search
# Random search is very similar to grid search, with the only difference, that instead of providing specific values for every hyperparameter, you only define a range for each hyperparameter - then, the values are sampled randomly from the provided ranges.
#
# ![alt text](https://i.stack.imgur.com/cIDuR.png "")
#
# The figure above illustrates the difference in the hyperparameter space exploration between grid search and random search: assume you have 2 hyperparameters with each 3 values. Running a grid search results in training $3^2=9$ different models - but in the end, you've just tired out 3 values for each parameter. For random search on the other hand, after training 9 models you'll have tried out 9 different values for each hyperparameter, which often leads much faster to good results.
#
# To get a deeper understanding of random search and why it is more efficient than grid search, you should definitely check out this paper: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf
#
# <div class="">
#     <h3>Task: Check Code</h3>
#     <p>Check out the <code>random_search</code> implementation in <code>dl_zero2one/hyperparameter_tuning.py</code></p>
# </div>
#
#
# *Hint: regarding the sample space of each parameter, think about the scale for which it makes most sense to sample in. For example the learning rate is usually sampled on a logarithmic scale!*
#
# *For simplicity and speed, just use the `train_batches`-dataloader!*

# %%
from dl_zero2one.hyperparameter_tuning import random_search
from dl_zero2one.networks import MyOwnNetwork

# Specify the used network
model_class = ClassificationNet

best_model, results = random_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([1e-2, 1e-6], 'log'),
        "reg": ([1e-3, 1e-7], "log"),
        "loss_func": ([CrossEntropyFromLogits()], "item")
    },
    model_class=model_class,
    num_search = 3, epochs=20, patience=5)
# Out:
# Evaluating Config #1 [of 3]:
#  {'learning_rate': 1.6125393319854112e-05, 'reg': 4.722337458533774e-06, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde5f70>}
# (Epoch 1 / 20) train loss: 2.302580; val loss: 2.302527
# (Epoch 2 / 20) train loss: 2.298985; val loss: 2.286194
# (Epoch 3 / 20) train loss: 2.265883; val loss: 2.220891
# (Epoch 4 / 20) train loss: 2.208952; val loss: 2.159681
# (Epoch 5 / 20) train loss: 2.169327; val loss: 2.127838
# (Epoch 6 / 20) train loss: 2.143435; val loss: 2.112909
# (Epoch 7 / 20) train loss: 2.124612; val loss: 2.106356
# (Epoch 8 / 20) train loss: 2.112977; val loss: 2.102943
# (Epoch 9 / 20) train loss: 2.102770; val loss: 2.103054
# (Epoch 10 / 20) train loss: 2.097548; val loss: 2.105739
# (Epoch 11 / 20) train loss: 2.093472; val loss: 2.109377
# (Epoch 12 / 20) train loss: 2.089133; val loss: 2.114887
# (Epoch 13 / 20) train loss: 2.087116; val loss: 2.117537
# Stopping early at epoch 12!
#
# Evaluating Config #2 [of 3]:
#  {'learning_rate': 1.459904734639263e-05, 'reg': 0.00023204211860687756, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde5f70>}
# (Epoch 1 / 20) train loss: 2.302731; val loss: 2.302752
# (Epoch 2 / 20) train loss: 2.299362; val loss: 2.288683
# (Epoch 3 / 20) train loss: 2.270998; val loss: 2.232427
# (Epoch 4 / 20) train loss: 2.220042; val loss: 2.173635
# (Epoch 5 / 20) train loss: 2.180494; val loss: 2.139982
# (Epoch 6 / 20) train loss: 2.153537; val loss: 2.120067
# (Epoch 7 / 20) train loss: 2.134948; val loss: 2.110740
# (Epoch 8 / 20) train loss: 2.120817; val loss: 2.106728
# (Epoch 9 / 20) train loss: 2.111426; val loss: 2.106298
# (Epoch 10 / 20) train loss: 2.104404; val loss: 2.107306
# (Epoch 11 / 20) train loss: 2.099037; val loss: 2.110180
# (Epoch 12 / 20) train loss: 2.094419; val loss: 2.115300
# (Epoch 13 / 20) train loss: 2.091778; val loss: 2.116219
# (Epoch 14 / 20) train loss: 2.089398; val loss: 2.118980
# Stopping early at epoch 13!
#
# Evaluating Config #3 [of 3]:
#  {'learning_rate': 0.00013117361193398406, 'reg': 2.9039763459248255e-07, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde5f70>}
# (Epoch 1 / 20) train loss: 2.302585; val loss: 2.302551
# (Epoch 2 / 20) train loss: 2.216366; val loss: 2.146064
# (Epoch 3 / 20) train loss: 2.108152; val loss: 2.152945
# (Epoch 4 / 20) train loss: 2.115136; val loss: 2.140395
# (Epoch 5 / 20) train loss: 2.096672; val loss: 2.152459
# (Epoch 6 / 20) train loss: 2.107950; val loss: 2.111305
# (Epoch 7 / 20) train loss: 2.073139; val loss: 2.111138
# (Epoch 8 / 20) train loss: 2.082920; val loss: 2.165388
# (Epoch 9 / 20) train loss: 2.080199; val loss: 2.137034
# (Epoch 10 / 20) train loss: 2.062291; val loss: 2.175490
# (Epoch 11 / 20) train loss: 2.059373; val loss: 2.122155
# (Epoch 12 / 20) train loss: 2.052151; val loss: 2.142287
# Stopping early at epoch 11!
#
# Search done. Best Val Loss = 2.1029428611757695
# Best Config: {'learning_rate': 1.6125393319854112e-05, 'reg': 4.722337458533774e-06, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde5f70>}

# %% [markdown]
# It's time to run it with the whole dataset, and let it search for a few hours for a nice configuration.
#
# However, to save some time, let's first implement an **early-stopping** mechanism, that you also already know from the lecture.

# %% [markdown]
# ## 3.3 Early Stopping

# %% [markdown]
# By now you've already seen a lot of training curves:
#
# <img src=http://fouryears.eu/wp-content/uploads/2017/12/early_stopping.png></img>
#
# Usually, at some point the validation loss goes up again, which is a sign that we're overfitting to our training data. Since it actually doesn't make any sense to train further at this point, it's common practice to apply "early stopping", i.e., cancel the training process when the validation loss doesn't improve anymore. The nice thing about this concept is, that not only it improves generalization through the prevention of overfitting, but also it saves us a lot of time - one of our most valuable resources in deep learning.
#
# Since there are natural fluctuations in the validation loss, you usually don't cancel the training process right at the first epoch when the validation-loss increases, but instead, you wait for some epochs (specified by the `patience`-parameter) and if the loss still doesn't improve, we stop.
#
# <div class="">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the early stopping mechanism in <code>dl_zero2one/solver.py</code>.
#  </p>
# </div>

# %% [markdown]
# ## 3.4 Let's find the perfect model!

# %% [markdown]
# You've now set everything up to start training your model and finding a nice set of hyper parameters using a combination of grid or random search!
#
# Since we'll now be training with a much larger number of samples, you should be aware that this process will definitely take some time! So be prepared to let your machine run for a while.
#
# At the beginning, it's a good approach to first do a coarse random search across a wide range of values to find promising sub-ranges of your parameter space. Afterwards, you can zoom in to these ranges and do another random search (or grid search) to finetune the configuration.
#
# You don't have to use the whole dataset at the beginning, instead you can also use a medium large subset of the samples. Also, you don't need to train for a large number of epochs - as mentioned above: we first want to get an overview about our hyper parameters.
#
# <div class="">
#     <h3>Task: Hyperparameters Tunning & Model Training </h3>
#         <p> Now, it is your turn to do the hyperparamater tuning. In the cell below, you can use the <code>random_search</code> function to find a good choice of parameters. Put in some reasonable ranges for the hyperparameters and evaluate them.
#     <p> <b>Note:</b> At the beginning, it's a good approach to first do a coarse random search across a <b> wide range of values</b> to find promising sub-ranges of your parameter space and use <b> a medium large subset of the dataset </b>instead the whole as well. Afterwards, you can zoom in to these ranges and do another random search (or grid search) to finetune the configuration. Use the cell below to play around and find good hyperparameters for your model!</p>
#         <p> Finally, once you've found some promising hyperparameters (or narrowed them down to promising subranges), it's time to utilize these hyperparameters to train your network on the whole dataset for a large number of epochs so that your own model can reach an acceptable performance.
#         <p> <b>Hint:</b> You may use a <code>Solver</code> class we provided before or directly use the <code>random_search</code> function (as you can also monitor the loss here) for model training.
# </div>

# %%
from dl_zero2one.networks import MyOwnNetwork

best_model = ClassificationNet()
#best_model = MyOwnNetwork()


best_model, results = random_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([5e-5, 1e-3], 'log'),
        "reg": ([1e-4, 1e-2], "log"),
        "loss_func": ([CrossEntropyFromLogits()], "item"),
        "hidden_size": ([192], "int"),
        "num_layer": ([2,5], "int"),
        "activation": ([LeakyRelu(), Tanh()], "item"),
        "optimizer": ([Adam], "item")
    },
    model_class=model_class,
    num_search = 25, epochs=20, patience=5)

#Best Config: {'learning_rate': 5.07112553051262e-05, 'reg': 0.0001, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x7f1428842610>, 'hidden_size': 153, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x7f14288425d0>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# Out:
# Evaluating Config #1 [of 25]:
#  {'learning_rate': 0.00011819534994639244, 'reg': 0.0006513996797979837, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452340>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302949; val loss: 2.302903
# (Epoch 2 / 20) train loss: 2.147642; val loss: 1.986047
# (Epoch 3 / 20) train loss: 1.893939; val loss: 1.907468
# (Epoch 4 / 20) train loss: 1.775659; val loss: 1.878006
# (Epoch 5 / 20) train loss: 1.671205; val loss: 1.839782
# (Epoch 6 / 20) train loss: 1.585436; val loss: 1.857473
# (Epoch 7 / 20) train loss: 1.502309; val loss: 1.815374
# (Epoch 8 / 20) train loss: 1.419842; val loss: 1.818163
# (Epoch 9 / 20) train loss: 1.339759; val loss: 1.814131
# (Epoch 10 / 20) train loss: 1.246358; val loss: 1.794661
# (Epoch 11 / 20) train loss: 1.173036; val loss: 1.854022
# (Epoch 12 / 20) train loss: 1.088510; val loss: 1.828749
# (Epoch 13 / 20) train loss: 1.010364; val loss: 1.819051
# (Epoch 14 / 20) train loss: 0.935112; val loss: 1.851538
# (Epoch 15 / 20) train loss: 0.862564; val loss: 1.897080
# Stopping early at epoch 14!
#
# Evaluating Config #2 [of 25]:
#  {'learning_rate': 0.00030953389234676925, 'reg': 0.00037673717449413836, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 4, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452340>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302836; val loss: 2.302836
# (Epoch 2 / 20) train loss: 2.302810; val loss: 2.302675
# (Epoch 3 / 20) train loss: 2.302401; val loss: 2.302813
# (Epoch 4 / 20) train loss: 2.302186; val loss: 2.302835
# (Epoch 5 / 20) train loss: 2.301925; val loss: 2.302925
# (Epoch 6 / 20) train loss: 2.301684; val loss: 2.303183
# (Epoch 7 / 20) train loss: 2.301481; val loss: 2.303200
# Stopping early at epoch 6!
#
# Evaluating Config #3 [of 25]:
#  {'learning_rate': 6.085845459124794e-05, 'reg': 0.0022941577809726006, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 4, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452340>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.304113; val loss: 2.304113
# (Epoch 2 / 20) train loss: 2.303445; val loss: 2.302999
# (Epoch 3 / 20) train loss: 2.302767; val loss: 2.302724
# (Epoch 4 / 20) train loss: 2.302541; val loss: 2.302662
# (Epoch 5 / 20) train loss: 2.302451; val loss: 2.302672
# (Epoch 6 / 20) train loss: 2.302387; val loss: 2.302680
# (Epoch 7 / 20) train loss: 2.302328; val loss: 2.302712
# (Epoch 8 / 20) train loss: 2.302275; val loss: 2.302716
# (Epoch 9 / 20) train loss: 2.302225; val loss: 2.302722
# Stopping early at epoch 8!
#
# Evaluating Config #4 [of 25]:
#  {'learning_rate': 0.000260306659596373, 'reg': 0.0003796382284716109, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 5, 'activation': <dl_zero2one.networks.layer.Tanh object at 0x12f452160>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302851; val loss: 2.302851
# (Epoch 2 / 20) train loss: 2.302804; val loss: 2.302755
# (Epoch 3 / 20) train loss: 2.302491; val loss: 2.302688
# (Epoch 4 / 20) train loss: 2.302199; val loss: 2.302868
# (Epoch 5 / 20) train loss: 2.302004; val loss: 2.302935
# (Epoch 6 / 20) train loss: 2.301831; val loss: 2.303139
# (Epoch 7 / 20) train loss: 2.301654; val loss: 2.303202
# (Epoch 8 / 20) train loss: 2.301387; val loss: 2.303481
# Stopping early at epoch 7!
#
# Evaluating Config #5 [of 25]:
#  {'learning_rate': 5.5316176581600664e-05, 'reg': 0.007626367595113877, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 5, 'activation': <dl_zero2one.networks.layer.Tanh object at 0x12f452160>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.307916; val loss: 2.307916
# (Epoch 2 / 20) train loss: 2.304022; val loss: 2.302735
# (Epoch 3 / 20) train loss: 2.302576; val loss: 2.302627
# (Epoch 4 / 20) train loss: 2.302503; val loss: 2.302628
# (Epoch 5 / 20) train loss: 2.302453; val loss: 2.302660
# (Epoch 6 / 20) train loss: 2.302409; val loss: 2.302684
# (Epoch 7 / 20) train loss: 2.302358; val loss: 2.302688
# (Epoch 8 / 20) train loss: 2.302313; val loss: 2.302704
# Stopping early at epoch 7!
#
# Evaluating Config #6 [of 25]:
#  {'learning_rate': 0.0009310402717982603, 'reg': 0.00589231363410301, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.Tanh object at 0x12f452160>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.306292; val loss: 2.306293
# (Epoch 2 / 20) train loss: 2.296521; val loss: 2.166009
# (Epoch 3 / 20) train loss: 2.227934; val loss: 2.194457
# (Epoch 4 / 20) train loss: 2.192497; val loss: 2.103834
# (Epoch 5 / 20) train loss: 2.163878; val loss: 2.227455
# (Epoch 6 / 20) train loss: 2.170783; val loss: 2.021555
# (Epoch 7 / 20) train loss: 2.155930; val loss: 2.130321
# (Epoch 8 / 20) train loss: 2.129591; val loss: 2.076113
# (Epoch 9 / 20) train loss: 2.150943; val loss: 2.205021
# (Epoch 10 / 20) train loss: 2.140484; val loss: 2.102750
# (Epoch 11 / 20) train loss: 2.135341; val loss: 2.046093
# Stopping early at epoch 10!
#
# Evaluating Config #7 [of 25]:
#  {'learning_rate': 0.0007326165086147845, 'reg': 0.0063418238675585804, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 4, 'activation': <dl_zero2one.networks.layer.Tanh object at 0x12f452160>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.306798; val loss: 2.306798
# (Epoch 2 / 20) train loss: 2.303005; val loss: 2.302918
# (Epoch 3 / 20) train loss: 2.302180; val loss: 2.303125
# (Epoch 4 / 20) train loss: 2.301740; val loss: 2.303401
# (Epoch 5 / 20) train loss: 2.301514; val loss: 2.303808
# (Epoch 6 / 20) train loss: 2.301136; val loss: 2.304020
# (Epoch 7 / 20) train loss: 2.301073; val loss: 2.304342
# Stopping early at epoch 6!
#
# Evaluating Config #8 [of 25]:
#  {'learning_rate': 0.00024366919417697172, 'reg': 0.001345500638542641, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.Tanh object at 0x12f452160>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.303502; val loss: 2.303518
# (Epoch 2 / 20) train loss: 2.103533; val loss: 2.023418
# (Epoch 3 / 20) train loss: 1.924879; val loss: 1.958296
# (Epoch 4 / 20) train loss: 1.823128; val loss: 1.892632
# (Epoch 5 / 20) train loss: 1.736695; val loss: 1.913863
# (Epoch 6 / 20) train loss: 1.662745; val loss: 1.921065
# (Epoch 7 / 20) train loss: 1.580545; val loss: 1.943330
# (Epoch 8 / 20) train loss: 1.502908; val loss: 1.900471
# (Epoch 9 / 20) train loss: 1.428221; val loss: 1.914429
# Stopping early at epoch 8!
#
# Evaluating Config #9 [of 25]:
#  {'learning_rate': 0.00020036617227657826, 'reg': 0.0002809611118388336, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452340>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302762; val loss: 2.302762
# (Epoch 2 / 20) train loss: 2.278970; val loss: 2.138017
# (Epoch 3 / 20) train loss: 2.115274; val loss: 2.070380
# (Epoch 4 / 20) train loss: 1.981489; val loss: 1.925551
# (Epoch 5 / 20) train loss: 1.843457; val loss: 1.872078
# (Epoch 6 / 20) train loss: 1.719517; val loss: 1.888548
# (Epoch 7 / 20) train loss: 1.619019; val loss: 1.885926
# (Epoch 8 / 20) train loss: 1.523376; val loss: 1.860646
# (Epoch 9 / 20) train loss: 1.449772; val loss: 1.847688
# (Epoch 10 / 20) train loss: 1.333435; val loss: 1.948138
# (Epoch 11 / 20) train loss: 1.277273; val loss: 1.950245
# (Epoch 12 / 20) train loss: 1.171029; val loss: 2.022484
# (Epoch 13 / 20) train loss: 1.049609; val loss: 2.009920
# (Epoch 14 / 20) train loss: 0.966850; val loss: 2.333644
# Stopping early at epoch 13!
#
# Evaluating Config #10 [of 25]:
#  {'learning_rate': 0.00013974760237379038, 'reg': 0.00010101040905972022, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452340>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302648; val loss: 2.302648
# (Epoch 2 / 20) train loss: 2.300566; val loss: 2.248812
# (Epoch 3 / 20) train loss: 2.131281; val loss: 2.103094
# (Epoch 4 / 20) train loss: 2.012116; val loss: 1.987456
# (Epoch 5 / 20) train loss: 1.864282; val loss: 1.939970
# (Epoch 6 / 20) train loss: 1.760214; val loss: 2.008798
# (Epoch 7 / 20) train loss: 1.668926; val loss: 1.952443
# (Epoch 8 / 20) train loss: 1.569849; val loss: 1.943898
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 13
#       3 best_model = ClassificationNet()
#       4 #best_model = MyOwnNetwork()
#       5
#       6 ########################################################################
#    (...)
#      10 # to upload the correct model!                                         #
#      11 ########################################################################
# ---> 13 best_model, results = random_search(
#      14     dataloaders['train_small'], dataloaders['val_500files'],
#      15     random_search_spaces = {
#      16         "learning_rate": ([5e-5, 1e-3], 'log'),
#      17         "reg": ([1e-4, 1e-2], "log"),
#      18         "loss_func": ([CrossEntropyFromLogits()], "item"),
#      19         "hidden_size": ([192], "int"),
#      20         "num_layer": ([2,5], "int"),
#      21         "activation": ([LeakyRelu(), Tanh()], "item"),
#      22         "optimizer": ([Adam], "item")
#      23     },
#      24     model_class=model_class,
#      25     num_search = 25, epochs=20, patience=5)
#      27 ########################################################################
#      28 #                           END OF YOUR CODE                           #
#      29 ########################################################################
#      30
#      31 #Best Config: {'learning_rate': 5.07112553051262e-05, 'reg': 0.0001, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x7f1428842610>, 'hidden_size': 153, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x7f14288425d0>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/hyperparameter_tuning.py:86, in random_search(train_loader, val_loader, random_search_spaces, model_class, num_search, epochs, patience)
#      83 for _ in range(num_search):
#      84     configs.append(random_search_spaces_to_config(random_search_spaces))
# ---> 86 return findBestConfig(train_loader, val_loader, configs, epochs, patience,
#      87                       model_class)
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/hyperparameter_tuning.py:109, in findBestConfig(train_loader, val_loader, configs, EPOCHS, PATIENCE, model_class)
#     107 model = model_class(**configs[i])
#     108 solver = Solver(model, train_loader, val_loader, **configs[i])
# --> 109 solver.train(epochs=EPOCHS, patience=PATIENCE)
#     110 results.append(solver.best_model_stats)
#     112 if not best_val or solver.best_model_stats["val_loss"] < best_val:
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/solver.py:137, in Solver.train(self, epochs, patience)
#     135 # Update the model parameters.
#     136 validate = t == 0
# --> 137 train_loss = self._step(X, y, validation=validate)
#     139 self.train_batch_loss.append(train_loss)
#     140 train_epoch_loss += train_loss
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/solver.py:115, in Solver._step(self, X, y, validation)
#     113     self.opt.backward(y_pred, y)
#     114     # Update weights
# --> 115     self.opt.step()
#     117 return loss
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/networks/optimizer.py:258, in Adam.step(self)
#     255 config = self.optim_configs[name]
#     257 # Update the parameter
# --> 258 w_updated, config = self._update(w, dw, config, lr=self.lr)
#     259 self.model.params[name] = w_updated
#     260 self.optim_configs[name] = config
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/networks/optimizer.py:232, in Adam._update(self, w, dw, config, lr)
#     230 m = beta1 * m + (1 - beta1) * dw
#     231 m_hat = m / (1 - np.power(beta1, t + 1))
# --> 232 v = beta2 * v + (1 - beta2) * (dw ** 2)
#     233 v_hat = v / (1 - np.power(beta2, t + 1))
#     234 next_w = w - learning_rate * m_hat / (np.sqrt(v_hat) + eps)
#
# KeyboardInterrupt:

# %% [markdown]
# Now a closer search for:  ```{'learning_rate': 0.00011819534994639244, 'reg': 0.0006513996797979837, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x13fde51c0>, 'hidden_size': 192, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452340>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}```

# %%
from dl_zero2one.networks import MyOwnNetwork

best_model = ClassificationNet()
#best_model = MyOwnNetwork()


best_model, results = random_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([8e-5, 8e-4], 'log'),
        "reg": ([4e-4, 2e-3], "log"),
        "loss_func": ([CrossEntropyFromLogits()], "item"),
        "hidden_size": ([100,192], "int"),
        "num_layer": ([2,3], "int"),
        "activation": ([LeakyRelu()], "item"),
        "optimizer": ([Adam], "item")
    },
    model_class=model_class,
    num_search = 25, epochs=20, patience=5)

#Best Config: {'learning_rate': 5.07112553051262e-05, 'reg': 0.0001, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x7f1428842610>, 'hidden_size': 153, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x7f14288425d0>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# Out:
# Evaluating Config #1 [of 25]:
#  {'learning_rate': 0.00013554134530018838, 'reg': 0.0008694914485493587, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 142, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302983; val loss: 2.302984
# (Epoch 2 / 20) train loss: 2.302834; val loss: 2.302557
# (Epoch 3 / 20) train loss: 2.204717; val loss: 2.102114
# (Epoch 4 / 20) train loss: 2.065332; val loss: 2.073874
# (Epoch 5 / 20) train loss: 1.999067; val loss: 2.091884
# (Epoch 6 / 20) train loss: 1.932822; val loss: 1.981368
# (Epoch 7 / 20) train loss: 1.818151; val loss: 2.078012
# (Epoch 8 / 20) train loss: 1.745740; val loss: 2.022624
# (Epoch 9 / 20) train loss: 1.665869; val loss: 1.909388
# (Epoch 10 / 20) train loss: 1.602029; val loss: 2.059457
# (Epoch 11 / 20) train loss: 1.538536; val loss: 2.030722
# (Epoch 12 / 20) train loss: 1.492569; val loss: 1.973720
# (Epoch 13 / 20) train loss: 1.441655; val loss: 1.987258
# (Epoch 14 / 20) train loss: 1.394324; val loss: 2.020439
# Stopping early at epoch 13!
#
# Evaluating Config #2 [of 25]:
#  {'learning_rate': 0.00013647621140104002, 'reg': 0.0004184896416912712, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 139, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302781; val loss: 2.302779
# (Epoch 2 / 20) train loss: 2.140276; val loss: 1.992012
# (Epoch 3 / 20) train loss: 1.886185; val loss: 1.906460
# (Epoch 4 / 20) train loss: 1.763765; val loss: 1.868394
# (Epoch 5 / 20) train loss: 1.670908; val loss: 1.835783
# (Epoch 6 / 20) train loss: 1.585397; val loss: 1.819585
# (Epoch 7 / 20) train loss: 1.498356; val loss: 1.784732
# (Epoch 8 / 20) train loss: 1.414537; val loss: 1.777575
# (Epoch 9 / 20) train loss: 1.332655; val loss: 1.809709
# (Epoch 10 / 20) train loss: 1.248554; val loss: 1.769584
# (Epoch 11 / 20) train loss: 1.163727; val loss: 1.792995
# (Epoch 12 / 20) train loss: 1.091157; val loss: 1.809999
# (Epoch 13 / 20) train loss: 1.009053; val loss: 1.785886
# (Epoch 14 / 20) train loss: 0.934988; val loss: 1.860892
# (Epoch 15 / 20) train loss: 0.856231; val loss: 1.835120
# Stopping early at epoch 14!
#
# Evaluating Config #3 [of 25]:
#  {'learning_rate': 0.00024968632116075776, 'reg': 0.0008234615638267361, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 157, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.303003; val loss: 2.303003
# (Epoch 2 / 20) train loss: 2.290059; val loss: 2.123688
# (Epoch 3 / 20) train loss: 2.126567; val loss: 2.158341
# (Epoch 4 / 20) train loss: 2.051228; val loss: 2.063602
# (Epoch 5 / 20) train loss: 1.927702; val loss: 2.152925
# (Epoch 6 / 20) train loss: 1.805577; val loss: 2.100789
# (Epoch 7 / 20) train loss: 1.726809; val loss: 1.921720
# (Epoch 8 / 20) train loss: 1.648657; val loss: 1.855645
# (Epoch 9 / 20) train loss: 1.566924; val loss: 1.984843
# (Epoch 10 / 20) train loss: 1.487002; val loss: 1.969953
# (Epoch 11 / 20) train loss: 1.410367; val loss: 1.850811
# (Epoch 12 / 20) train loss: 1.350994; val loss: 2.060137
# (Epoch 13 / 20) train loss: 1.265175; val loss: 2.160186
# (Epoch 14 / 20) train loss: 1.172628; val loss: 2.132808
# (Epoch 15 / 20) train loss: 1.136010; val loss: 2.190240
# (Epoch 16 / 20) train loss: 1.044532; val loss: 2.486851
# Stopping early at epoch 15!
#
# Evaluating Config #4 [of 25]:
#  {'learning_rate': 0.00024256421454071442, 'reg': 0.0009958466822222942, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 106, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302921; val loss: 2.302922
# (Epoch 2 / 20) train loss: 2.302396; val loss: 2.289474
# (Epoch 3 / 20) train loss: 2.177702; val loss: 2.094939
# (Epoch 4 / 20) train loss: 2.070470; val loss: 2.059291
# (Epoch 5 / 20) train loss: 1.977670; val loss: 2.063666
# (Epoch 6 / 20) train loss: 1.861195; val loss: 2.036870
# (Epoch 7 / 20) train loss: 1.783462; val loss: 1.985345
# (Epoch 8 / 20) train loss: 1.715724; val loss: 1.966018
# (Epoch 9 / 20) train loss: 1.636386; val loss: 1.910687
# (Epoch 10 / 20) train loss: 1.588993; val loss: 1.952701
# (Epoch 11 / 20) train loss: 1.515426; val loss: 1.997506
# (Epoch 12 / 20) train loss: 1.464955; val loss: 1.947489
# (Epoch 13 / 20) train loss: 1.403796; val loss: 1.986940
# (Epoch 14 / 20) train loss: 1.324170; val loss: 2.133287
# Stopping early at epoch 13!
#
# Evaluating Config #5 [of 25]:
#  {'learning_rate': 0.0006932449858358148, 'reg': 0.0011396985782337783, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 141, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.303087; val loss: 2.303166
# (Epoch 2 / 20) train loss: 2.134766; val loss: 2.081209
# (Epoch 3 / 20) train loss: 1.893674; val loss: 2.067733
# (Epoch 4 / 20) train loss: 1.749980; val loss: 1.989111
# (Epoch 5 / 20) train loss: 1.652135; val loss: 1.946792
# (Epoch 6 / 20) train loss: 1.523310; val loss: 2.232588
# (Epoch 7 / 20) train loss: 1.426548; val loss: 2.111017
# (Epoch 8 / 20) train loss: 1.297014; val loss: 2.081980
# (Epoch 9 / 20) train loss: 1.216982; val loss: 2.103776
# (Epoch 10 / 20) train loss: 1.080420; val loss: 2.294105
# Stopping early at epoch 9!
#
# Evaluating Config #6 [of 25]:
#  {'learning_rate': 0.0004304771957644432, 'reg': 0.0010520477549850553, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 160, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.303125; val loss: 2.303150
# (Epoch 2 / 20) train loss: 2.063434; val loss: 1.925057
# (Epoch 3 / 20) train loss: 1.839014; val loss: 1.843722
# (Epoch 4 / 20) train loss: 1.687827; val loss: 1.904880
# (Epoch 5 / 20) train loss: 1.570637; val loss: 1.816332
# (Epoch 6 / 20) train loss: 1.425463; val loss: 1.940614
# (Epoch 7 / 20) train loss: 1.297735; val loss: 2.091180
# (Epoch 8 / 20) train loss: 1.174978; val loss: 2.032615
# (Epoch 9 / 20) train loss: 1.033238; val loss: 2.044169
# (Epoch 10 / 20) train loss: 0.979717; val loss: 2.077431
# Stopping early at epoch 9!
#
# Evaluating Config #7 [of 25]:
#  {'learning_rate': 8.593327912746212e-05, 'reg': 0.001184378648635231, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 156, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.303183; val loss: 2.303183
# (Epoch 2 / 20) train loss: 2.302972; val loss: 2.302838
# (Epoch 3 / 20) train loss: 2.302348; val loss: 2.298068
# (Epoch 4 / 20) train loss: 2.180941; val loss: 2.106349
# (Epoch 5 / 20) train loss: 2.066381; val loss: 2.080425
# (Epoch 6 / 20) train loss: 2.012000; val loss: 2.064914
# (Epoch 7 / 20) train loss: 1.966428; val loss: 2.065297
# (Epoch 8 / 20) train loss: 1.907192; val loss: 2.025807
# (Epoch 9 / 20) train loss: 1.836602; val loss: 2.060280
# (Epoch 10 / 20) train loss: 1.767700; val loss: 1.984877
# (Epoch 11 / 20) train loss: 1.721375; val loss: 2.009445
# (Epoch 12 / 20) train loss: 1.665692; val loss: 1.982349
# (Epoch 13 / 20) train loss: 1.613989; val loss: 2.013812
# (Epoch 14 / 20) train loss: 1.577120; val loss: 1.962279
# (Epoch 15 / 20) train loss: 1.527679; val loss: 1.978282
# (Epoch 16 / 20) train loss: 1.497775; val loss: 2.006706
# (Epoch 17 / 20) train loss: 1.460329; val loss: 2.036373
# (Epoch 18 / 20) train loss: 1.424434; val loss: 2.074876
# (Epoch 19 / 20) train loss: 1.381832; val loss: 2.095393
# Stopping early at epoch 18!
#
# Evaluating Config #8 [of 25]:
#  {'learning_rate': 0.0001183182890376935, 'reg': 0.00041279943975557163, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 122, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302746; val loss: 2.302746
# (Epoch 2 / 20) train loss: 2.302703; val loss: 2.302450
# (Epoch 3 / 20) train loss: 2.214487; val loss: 2.143587
# (Epoch 4 / 20) train loss: 2.067507; val loss: 2.081414
# (Epoch 5 / 20) train loss: 2.007005; val loss: 2.052292
# (Epoch 6 / 20) train loss: 1.955533; val loss: 2.027848
# (Epoch 7 / 20) train loss: 1.859905; val loss: 1.978715
# (Epoch 8 / 20) train loss: 1.774983; val loss: 2.025081
# (Epoch 9 / 20) train loss: 1.701390; val loss: 1.999976
# (Epoch 10 / 20) train loss: 1.646587; val loss: 2.007871
# (Epoch 11 / 20) train loss: 1.595380; val loss: 1.936091
# (Epoch 12 / 20) train loss: 1.532039; val loss: 2.032057
# (Epoch 13 / 20) train loss: 1.481765; val loss: 2.011355
# (Epoch 14 / 20) train loss: 1.435357; val loss: 2.006949
# (Epoch 15 / 20) train loss: 1.380900; val loss: 2.087690
# (Epoch 16 / 20) train loss: 1.338087; val loss: 2.098672
# Stopping early at epoch 15!
#
# Evaluating Config #9 [of 25]:
#  {'learning_rate': 0.00020126407394001493, 'reg': 0.0005167572058852692, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 147, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302812; val loss: 2.302795
# (Epoch 2 / 20) train loss: 2.104841; val loss: 1.961712
# (Epoch 3 / 20) train loss: 1.849345; val loss: 1.845214
# (Epoch 4 / 20) train loss: 1.698318; val loss: 1.847283
# (Epoch 5 / 20) train loss: 1.587453; val loss: 1.818175
# (Epoch 6 / 20) train loss: 1.465981; val loss: 1.796930
# (Epoch 7 / 20) train loss: 1.344618; val loss: 1.846811
# (Epoch 8 / 20) train loss: 1.233122; val loss: 1.811292
# (Epoch 9 / 20) train loss: 1.114896; val loss: 1.836975
# (Epoch 10 / 20) train loss: 1.000462; val loss: 1.843389
# (Epoch 11 / 20) train loss: 0.899228; val loss: 1.924905
# Stopping early at epoch 10!
#
# Evaluating Config #10 [of 25]:
#  {'learning_rate': 9.127290909473511e-05, 'reg': 0.0014830597064548067, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 184, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.303474; val loss: 2.303473
# (Epoch 2 / 20) train loss: 2.303104; val loss: 2.302830
# (Epoch 3 / 20) train loss: 2.301477; val loss: 2.279696
# (Epoch 4 / 20) train loss: 2.172666; val loss: 2.096515
# (Epoch 5 / 20) train loss: 2.067674; val loss: 2.111608
# (Epoch 6 / 20) train loss: 2.023546; val loss: 2.090351
# (Epoch 7 / 20) train loss: 1.971936; val loss: 2.079525
# (Epoch 8 / 20) train loss: 1.902889; val loss: 2.064926
# (Epoch 9 / 20) train loss: 1.812153; val loss: 1.961174
# (Epoch 10 / 20) train loss: 1.761983; val loss: 1.990364
# (Epoch 11 / 20) train loss: 1.704080; val loss: 2.016853
# (Epoch 12 / 20) train loss: 1.660104; val loss: 2.134989
# (Epoch 13 / 20) train loss: 1.623286; val loss: 2.043444
# (Epoch 14 / 20) train loss: 1.564300; val loss: 2.022422
# Stopping early at epoch 13!
#
# Evaluating Config #11 [of 25]:
#  {'learning_rate': 0.0001304217538543971, 'reg': 0.0005869362970596999, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 137, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302813; val loss: 2.302852
# (Epoch 2 / 20) train loss: 2.152363; val loss: 1.984729
# (Epoch 3 / 20) train loss: 1.900051; val loss: 1.887215
# (Epoch 4 / 20) train loss: 1.775215; val loss: 1.833425
# (Epoch 5 / 20) train loss: 1.683115; val loss: 1.826497
# (Epoch 6 / 20) train loss: 1.601090; val loss: 1.800764
# (Epoch 7 / 20) train loss: 1.521218; val loss: 1.819926
# (Epoch 8 / 20) train loss: 1.445261; val loss: 1.839117
# (Epoch 9 / 20) train loss: 1.368549; val loss: 1.836590
# (Epoch 10 / 20) train loss: 1.290281; val loss: 1.812893
# (Epoch 11 / 20) train loss: 1.217753; val loss: 1.806513
# Stopping early at epoch 10!
#
# Evaluating Config #12 [of 25]:
#  {'learning_rate': 9.319947637084098e-05, 'reg': 0.00141384563326066, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 172, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.303325; val loss: 2.303261
# (Epoch 2 / 20) train loss: 2.181905; val loss: 2.023343
# (Epoch 3 / 20) train loss: 1.954669; val loss: 1.931597
# (Epoch 4 / 20) train loss: 1.838189; val loss: 1.882210
# (Epoch 5 / 20) train loss: 1.758404; val loss: 1.857674
# (Epoch 6 / 20) train loss: 1.690984; val loss: 1.856501
# (Epoch 7 / 20) train loss: 1.623741; val loss: 1.839666
# (Epoch 8 / 20) train loss: 1.562024; val loss: 1.826598
# (Epoch 9 / 20) train loss: 1.505116; val loss: 1.833882
# (Epoch 10 / 20) train loss: 1.442734; val loss: 1.822036
# (Epoch 11 / 20) train loss: 1.392700; val loss: 1.843156
# (Epoch 12 / 20) train loss: 1.331978; val loss: 1.848183
# (Epoch 13 / 20) train loss: 1.280047; val loss: 1.792109
# (Epoch 14 / 20) train loss: 1.220572; val loss: 1.838415
# (Epoch 15 / 20) train loss: 1.166265; val loss: 1.825798
# (Epoch 16 / 20) train loss: 1.110778; val loss: 1.831484
# (Epoch 17 / 20) train loss: 1.064626; val loss: 1.864342
# (Epoch 18 / 20) train loss: 1.005389; val loss: 1.838557
# Stopping early at epoch 17!
#
# Evaluating Config #13 [of 25]:
#  {'learning_rate': 0.00022563020010632126, 'reg': 0.0005071309470566738, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 119, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302777; val loss: 2.302777
# (Epoch 2 / 20) train loss: 2.298265; val loss: 2.218076
# (Epoch 3 / 20) train loss: 2.134131; val loss: 2.110663
# (Epoch 4 / 20) train loss: 2.043209; val loss: 2.044026
# (Epoch 5 / 20) train loss: 1.910657; val loss: 2.026012
# (Epoch 6 / 20) train loss: 1.782097; val loss: 1.964255
# (Epoch 7 / 20) train loss: 1.686257; val loss: 2.002511
# (Epoch 8 / 20) train loss: 1.611998; val loss: 1.970435
# (Epoch 9 / 20) train loss: 1.530356; val loss: 1.873567
# (Epoch 10 / 20) train loss: 1.470403; val loss: 1.961947
# (Epoch 11 / 20) train loss: 1.382907; val loss: 2.081701
# (Epoch 12 / 20) train loss: 1.335080; val loss: 2.144248
# (Epoch 13 / 20) train loss: 1.243849; val loss: 2.201036
# (Epoch 14 / 20) train loss: 1.195808; val loss: 2.261119
# Stopping early at epoch 13!
#
# Evaluating Config #14 [of 25]:
#  {'learning_rate': 0.0006894367508262977, 'reg': 0.0009961769525766396, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 113, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.302910; val loss: 2.302962
# (Epoch 2 / 20) train loss: 2.112622; val loss: 1.984287
# (Epoch 3 / 20) train loss: 1.858180; val loss: 1.890630
# (Epoch 4 / 20) train loss: 1.714942; val loss: 1.960182
# (Epoch 5 / 20) train loss: 1.575538; val loss: 2.059042
# (Epoch 6 / 20) train loss: 1.512160; val loss: 2.138161
# (Epoch 7 / 20) train loss: 1.334788; val loss: 2.082609
# (Epoch 8 / 20) train loss: 1.270665; val loss: 2.087063
# Stopping early at epoch 7!
#
# Evaluating Config #15 [of 25]:
#  {'learning_rate': 0.00046144663496409006, 'reg': 0.0015036584428224393, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x12f4522b0>, 'hidden_size': 108, 'num_layer': 3, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x12f452490>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
# (Epoch 1 / 20) train loss: 2.303105; val loss: 2.303105
# (Epoch 2 / 20) train loss: 2.302730; val loss: 2.302779
# (Epoch 3 / 20) train loss: 2.302266; val loss: 2.302871
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 7
#       3 best_model = ClassificationNet()
#       4 #best_model = MyOwnNetwork()
# ----> 7 best_model, results = random_search(
#       8     dataloaders['train_small'], dataloaders['val_500files'],
#       9     random_search_spaces = {
#      10         "learning_rate": ([8e-5, 8e-4], 'log'),
#      11         "reg": ([4e-4, 2e-3], "log"),
#      12         "loss_func": ([CrossEntropyFromLogits()], "item"),
#      13         "hidden_size": ([100,192], "int"),
#      14         "num_layer": ([2,3], "int"),
#      15         "activation": ([LeakyRelu()], "item"),
#      16         "optimizer": ([Adam], "item")
#      17     },
#      18     model_class=model_class,
#      19     num_search = 25, epochs=20, patience=5)
#      21 #Best Config: {'learning_rate': 5.07112553051262e-05, 'reg': 0.0001, 'loss_func': <dl_zero2one.networks.loss.CrossEntropyFromLogits object at 0x7f1428842610>, 'hidden_size': 153, 'num_layer': 2, 'activation': <dl_zero2one.networks.layer.LeakyRelu object at 0x7f14288425d0>, 'optimizer': <class 'dl_zero2one.networks.optimizer.Adam'>}
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/hyperparameter_tuning.py:86, in random_search(train_loader, val_loader, random_search_spaces, model_class, num_search, epochs, patience)
#      83 for _ in range(num_search):
#      84     configs.append(random_search_spaces_to_config(random_search_spaces))
# ---> 86 return findBestConfig(train_loader, val_loader, configs, epochs, patience,
#      87                       model_class)
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/hyperparameter_tuning.py:109, in findBestConfig(train_loader, val_loader, configs, EPOCHS, PATIENCE, model_class)
#     107 model = model_class(**configs[i])
#     108 solver = Solver(model, train_loader, val_loader, **configs[i])
# --> 109 solver.train(epochs=EPOCHS, patience=PATIENCE)
#     110 results.append(solver.best_model_stats)
#     112 if not best_val or solver.best_model_stats["val_loss"] < best_val:
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/solver.py:137, in Solver.train(self, epochs, patience)
#     135 # Update the model parameters.
#     136 validate = t == 0
# --> 137 train_loss = self._step(X, y, validation=validate)
#     139 self.train_batch_loss.append(train_loss)
#     140 train_epoch_loss += train_loss
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/solver.py:113, in Solver._step(self, X, y, validation)
#     110 # Perform gradient update (only in train mode)
#     111 if not validation:
#     112     # Compute gradients
# --> 113     self.opt.backward(y_pred, y)
#     114     # Update weights
#     115     self.opt.step()
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/networks/optimizer.py:205, in Adam.backward(self, y_pred, y_true)
#     201 """
#     202 Compute the gradients wrt the weights of your model
#     203 """
#     204 dout = self.loss_func.backward(y_pred, y_true)
# --> 205 self.model.backward(dout)
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/networks/classification_net.py:123, in ClassificationNet.backward(self, dy)
#     120 dh = self.activation.backward(dh, cache_sigmoid)
#     122 # Affine backward
# --> 123 dh, dW, db = affine_backward(dh, cache_affine)
#     125 # Refresh the gradients
#     126 self.grads['W' + str(i + 1)] = dW + 2 * self.reg_strength * \
#     127     self.params['W' + str(i + 1)]
#
# File ~/Documents/Coding/deeplearning-zero-to-one/dl_zero2one/networks/layer.py:168, in affine_backward(dout, cache)
#     164 dx = (dout @ w.T).reshape(x.shape)
#     166 x_reshaped = np.reshape(x, (N, D))
# --> 168 dw = x_reshaped.T @ dout
#     170 db = np.mean(dout, axis=0)
#     171 db = np.reshape(db, b.shape[0])
#
# KeyboardInterrupt:

# %%
# Create a dataloader for each split.


# Use the Cifar10 mean and standard deviation computed in Exercise 4.
cifar_mean = np.array([0.49191375, 0.48235852, 0.44673872])
cifar_std  = np.array([0.24706447, 0.24346213, 0.26147554])

# Define all the transforms we will apply on the images when 
# retrieving them.
rescale_transform = RescaleTransform()
normalize_transform = NormalizeTransform(
    mean=cifar_mean,
    std=cifar_std
)
flatten_transform = FlattenTransform()
compose_transform = ComposeTransform([rescale_transform, 
                                      normalize_transform,
                                      flatten_transform])

# Create a train, validation and test dataset.
datasets = {}
for mode in ['val', 'test']:
    crt_dataset = ImageFolderDataset(
        mode=mode,
        root=cifar_root, 
        transform=compose_transform,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2}
    )
    datasets[mode] = crt_dataset



transform_train = ComposeTransform([
                rescale_transform,
                normalize_transform,
                RandomHorizontalFlip(),
                flatten_transform])

datasets['train'] = ImageFolderDataset(
        mode='train',
        root=cifar_root, 
        transform=transform_train,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2}
    )

#dataloaders = {}
for mode in ['train','val', 'test']:
    crt_dataloader = DataLoader(
        dataset=datasets[mode],
        batch_size=512,
        shuffle=True,
        drop_last=True,
    )
    dataloaders[mode] = crt_dataloader

# %%
from dl_zero2one.networks import MyOwnNetwork

#best_model = ClassificationNet()
#best_model = MyOwnNetwork()


from dl_zero2one.networks import MyOwnNetwork

num_layer = 2
hidden_size = 256
epochs = 140
reg=1e-4
activation = LeakyRelu()
lr_decay = 0.98
std = 1e-3
learning_rate=3e-3



best_model = ClassificationNet(num_layer=num_layer, reg=reg, activation=activation, std=std)
# model = MyOwnNetwork()

# %%
# Change here if you want to use the full training set
use_full_training_set = True
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']

loss = CrossEntropyFromLogits()

solver = Solver(best_model, train_loader, dataloaders['val'], 
                learning_rate=learning_rate, loss_func=loss, optimizer=Adam, lr_decay=lr_decay)

solver.train(epochs=epochs, patience=5)
# Out:
# (Epoch 1 / 140) train loss: 2.302654; val loss: 2.302653
# (Epoch 2 / 140) train loss: 2.275074; val loss: 2.185535
# (Epoch 3 / 140) train loss: 2.075951; val loss: 1.982913
# (Epoch 4 / 140) train loss: 1.931477; val loss: 1.877078
# (Epoch 5 / 140) train loss: 1.849342; val loss: 1.815280
# (Epoch 6 / 140) train loss: 1.805228; val loss: 1.785624
# (Epoch 7 / 140) train loss: 1.776395; val loss: 1.760194
# (Epoch 8 / 140) train loss: 1.757232; val loss: 1.745920
# (Epoch 9 / 140) train loss: 1.740966; val loss: 1.731246
# (Epoch 10 / 140) train loss: 1.727748; val loss: 1.717660
# (Epoch 11 / 140) train loss: 1.715700; val loss: 1.710756
# (Epoch 12 / 140) train loss: 1.704252; val loss: 1.697042
# (Epoch 13 / 140) train loss: 1.694651; val loss: 1.694994
# (Epoch 14 / 140) train loss: 1.687800; val loss: 1.686279
# (Epoch 15 / 140) train loss: 1.680914; val loss: 1.680951
# (Epoch 16 / 140) train loss: 1.677448; val loss: 1.674773
# (Epoch 17 / 140) train loss: 1.671933; val loss: 1.671041
# (Epoch 18 / 140) train loss: 1.666413; val loss: 1.671290
# (Epoch 19 / 140) train loss: 1.666047; val loss: 1.669146
# (Epoch 20 / 140) train loss: 1.662749; val loss: 1.665045
# (Epoch 21 / 140) train loss: 1.659152; val loss: 1.660299
# (Epoch 22 / 140) train loss: 1.657869; val loss: 1.660652
# (Epoch 23 / 140) train loss: 1.656670; val loss: 1.659861
# (Epoch 24 / 140) train loss: 1.654580; val loss: 1.654813
# (Epoch 25 / 140) train loss: 1.651517; val loss: 1.657534
# (Epoch 26 / 140) train loss: 1.650810; val loss: 1.658876
# (Epoch 27 / 140) train loss: 1.650381; val loss: 1.655115
# (Epoch 28 / 140) train loss: 1.650267; val loss: 1.653110
# (Epoch 29 / 140) train loss: 1.648044; val loss: 1.651620
# (Epoch 30 / 140) train loss: 1.646262; val loss: 1.648381
# (Epoch 31 / 140) train loss: 1.646215; val loss: 1.649522
# (Epoch 32 / 140) train loss: 1.643242; val loss: 1.649023
# (Epoch 33 / 140) train loss: 1.643080; val loss: 1.648350
# (Epoch 34 / 140) train loss: 1.641407; val loss: 1.647625
# (Epoch 35 / 140) train loss: 1.640097; val loss: 1.646480
# (Epoch 36 / 140) train loss: 1.640822; val loss: 1.645675
# (Epoch 37 / 140) train loss: 1.640261; val loss: 1.645146
# (Epoch 38 / 140) train loss: 1.639186; val loss: 1.643371
# (Epoch 39 / 140) train loss: 1.638260; val loss: 1.645029
# (Epoch 40 / 140) train loss: 1.637222; val loss: 1.644000
# (Epoch 41 / 140) train loss: 1.637469; val loss: 1.642307
# (Epoch 42 / 140) train loss: 1.636074; val loss: 1.643285
# (Epoch 43 / 140) train loss: 1.636818; val loss: 1.642925
# (Epoch 44 / 140) train loss: 1.635547; val loss: 1.644743
# (Epoch 45 / 140) train loss: 1.634666; val loss: 1.643745
# (Epoch 46 / 140) train loss: 1.633810; val loss: 1.642219
# (Epoch 47 / 140) train loss: 1.633613; val loss: 1.639546
# (Epoch 48 / 140) train loss: 1.632693; val loss: 1.640307
# (Epoch 49 / 140) train loss: 1.632393; val loss: 1.642116
# (Epoch 50 / 140) train loss: 1.632167; val loss: 1.638282
# (Epoch 51 / 140) train loss: 1.631191; val loss: 1.638852
# (Epoch 52 / 140) train loss: 1.630485; val loss: 1.638624
# (Epoch 53 / 140) train loss: 1.630167; val loss: 1.638095
# (Epoch 54 / 140) train loss: 1.630544; val loss: 1.639326
# (Epoch 55 / 140) train loss: 1.629343; val loss: 1.637642
# (Epoch 56 / 140) train loss: 1.629319; val loss: 1.638006
# (Epoch 57 / 140) train loss: 1.629342; val loss: 1.637518
# (Epoch 58 / 140) train loss: 1.627953; val loss: 1.636703
# (Epoch 59 / 140) train loss: 1.627204; val loss: 1.635515
# (Epoch 60 / 140) train loss: 1.628379; val loss: 1.634389
# (Epoch 61 / 140) train loss: 1.626604; val loss: 1.635262
# (Epoch 62 / 140) train loss: 1.626973; val loss: 1.635568
# (Epoch 63 / 140) train loss: 1.627198; val loss: 1.636502
# (Epoch 64 / 140) train loss: 1.627435; val loss: 1.635054
# (Epoch 65 / 140) train loss: 1.626185; val loss: 1.633666
# (Epoch 66 / 140) train loss: 1.626451; val loss: 1.634878
# (Epoch 67 / 140) train loss: 1.625636; val loss: 1.634201
# (Epoch 68 / 140) train loss: 1.625598; val loss: 1.633892
# (Epoch 69 / 140) train loss: 1.625568; val loss: 1.632351
# (Epoch 70 / 140) train loss: 1.624338; val loss: 1.631232
# (Epoch 71 / 140) train loss: 1.624559; val loss: 1.635224
# (Epoch 72 / 140) train loss: 1.624590; val loss: 1.633259
# (Epoch 73 / 140) train loss: 1.623894; val loss: 1.635286
# (Epoch 74 / 140) train loss: 1.623012; val loss: 1.633389
# (Epoch 75 / 140) train loss: 1.624206; val loss: 1.630629
# (Epoch 76 / 140) train loss: 1.623667; val loss: 1.632511
# (Epoch 77 / 140) train loss: 1.623056; val loss: 1.629879
# (Epoch 78 / 140) train loss: 1.622704; val loss: 1.631798
# (Epoch 79 / 140) train loss: 1.622339; val loss: 1.632029
# (Epoch 80 / 140) train loss: 1.621994; val loss: 1.632432
# (Epoch 81 / 140) train loss: 1.622978; val loss: 1.633298
# (Epoch 82 / 140) train loss: 1.621668; val loss: 1.632007
# Stopping early at epoch 81!

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %% [markdown]
# Now it's time to edit the ranges above and adjust them to explore regions that performed well!
#
# Also, feel free to experiment around! Also the network architecture, optimizer options and activations functions, etc. are hyperparameters that you can change!
#
# Try to get your accuracy as high as possible! That's all what counts for this submission!
#
# You'll pass if you reach at least **48%** accuracy on our test set - but there will also be a leaderboard of all students of this course. Will you make it to the top?

# %% [markdown]
# ## 3.5 Checking the validation accuracy

# %%
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['train'])
print("Train Accuracy: {}%".format(acc*100))
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['val'])
print("Validation Accuracy: {}%".format(acc*100))
# Out:
# Train Accuracy: 44.352774784482754%
# Validation Accuracy: 43.575246710526315%

# %% [markdown]
# # 4. Test your model
# When you have finished your hyperparameter tuning and are sure you have your final model that performs well on the validation set (**you should at least get 43% accuracy on the validation set!**), it's time to run your  model on the test set.
#
# <div class="alert alert-danger">
#     <h3>Important</h3>
#     <p>You must only use the test set one single time! So only run the next cell if you are really sure your model works well enough. Nevertheless, you will have a reasonable close approximation about your performance if you only do a final evaluation on the test set.</p>
# </div>

# %%
# comment this part out to see your model's performance on the test set.
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['test'])
print("Test Accuracy: {}%".format(acc*100))
# Out:
# Test Accuracy: 44.3359375%
